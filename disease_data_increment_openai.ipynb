# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-genzeon/AI-ML-Bootcamp-Genzeon-2023/blob/master/disease_data_increment_openai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (0.27.8)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)

# %%
import pandas as pd
import numpy as np
import openai


# Set up OpenAI API credentials
openai.api_key = "*"

# Define the prompt
prompt = "New diseases with it's symptoms from your knowledge base which is not present in the dataset:"

# Read the dataset from a CSV file

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataSet/dataset.csv")  # Replace with the path to your CSV file

# Split the dataset into smaller chunks
token_limit = 4097 - len(prompt)
dataset_chunks = [chunk.to_string(index=False)[:token_limit] for chunk in np.array_split(df, len(df) // 200 + 1)]

# Generate diseases and symptoms
def generate_diseases_and_symptoms(dataset_chunks):
    results = []s

    for chunk in dataset_chunks:

        response = openai.Completion.create(

            engine="text-davinci-003",

            prompt=prompt + chunk,

            max_tokens=50,

            n=5,

            stop=None,

            temperature=0.8,

            top_p=1.0

        )

        completions = response.choices

        generated_data = [completion.text.strip().split("|") for completion in completions]

        results.extend(generated_data)

    return results

# Process and present the generated results

def present_results(results):

    for result in results:

        disease = result[0]

        symptoms = result[1:]

        print("Disease:", disease)

        print("Symptoms:", symptoms)

        print()

# Example usage

generated_results = generate_diseases_and_symptoms(dataset_chunks)

present_results(generated_results)
# Out:
# Disease: ns                         oedema                       fever                    fatigue                headache                  anemia                  weight_loss              diarrhea          nausea                  vomiting                  abdominal_pain        bloating        nausea        dizziness
# Symptoms: []
#
# Disease: ,ns              fever                  joint_pain                  headache               fatigue                 chills                  nausea                  vomiting                 diarrhea          feverishness                   dizziness        confusion        blurred_vision   abdominal_pain
# Symptoms: []
#
# Disease: in                        fatigue                   fever                  chills                 sweats                headache               body_ache            joint_pain            muscle_pain            vomiting          nausea                  dehydration                NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: ns            fever                headache              fatigue               chills               muscle_ache             joint_pain            nausea                  vomiting             diarrhea          abdominal_pain      appetite_loss      weight_loss       dehydration   blurred_vision
# Symptoms: []
#
# Disease: loss_of_appetite              fatigue                    fever                  chills                    nausea                   vomiting                 headaches            body_pain              swollen_lymph_nodes   joint_pain          abdominal_pain        chest_pain          breathing_difficult
# Symptoms: []
#
# Disease: _urine         yellowing_of_eyes                   malaise  receiving_blood_transfusion  receiving_unsterile_injections                    NaN           NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: _urine         yellowing_of_eyes                   malaise  receiving_blood_transfusion  receiving_unsterile_injections                             NaN                    NaN         NaN              NaN              NaN          Na
# Symptoms: []
#
# Disease: _urine         yellowing_of_eyes                   malaise  receiving_blood_transfusion  receiving_unsterile_injections                             NaN                    NaN         NaN              NaN              NaN          Na
# Symptoms: []
#
# Disease: _urine         yellowing_of_eyes                   malaise  receiving_blood_transfusion  receiving_unsterile_injections                             NaN                    NaN         NaN              NaN              NaN          Na
# Symptoms: []
#
# Disease: _urine         yellowing_of_eyes                   malaise  receiving_blood_transfusion  receiving_unsterile_injections                             NaN                    NaN         NaN              NaN              NaN          Na
# Symptoms: []
#
# Disease: se            yellow_crust_ooze                           NaN                           NaN                NaN                  NaN                   NaN                   NaN                  NaN          NaN                  NaN                  NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: ce             yellow_crust_ooze                           NaN                NaN                  NaN                   NaN                   NaN                  NaN          NaN                  NaN                  NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: ze             yellow_crust_ooze                           NaN                           NaN                NaN                  NaN                   NaN                   NaN                  NaN          NaN                  NaN                  NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: ise            yellow_crust_ooze                           NaN                NaN                  NaN                   NaN                   NaN                  NaN          NaN                  NaN                  NaN        NaN        NaN        NaN
#                     Impet
# Symptoms: []
#
# Disease: ise            yellow_crust_ooze                           NaN                           NaN                NaN                  NaN                   NaN                   NaN                  NaN          NaN                  NaN                  NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: toxic_look_(typhos)                   belly_pain                      muscle_aches                    joint_pain                    NaN         NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: toxic_look_(typhos)                      belly_pain                             NaN                             NaN                    NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: muscle_and_joint_pain          toxic_look_(typhos)                      belly_pain                    jaundice                     NaN         NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: skin_rash or spot_(typhos)                   belly_pain                             NaN                    NaN         NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: anorexia_and_weight_loss                    NaN                             NaN                    NaN         NaN              NaN              NaN          NaN
#                                 Typhoid                       chills                     vomiting               fatigue             high_fever                        headache
# Symptoms: []
#
# Disease: abdominal_Pain        NaN
# Symptoms: []
#
# Disease: abdominal_pain           vomiting                  nausea                   fever                         NaN                           NaN                           NaN                NaN                  NaN                  NaN                  NaN                  NaN        NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease: abdominal_pain        NaN
# Symptoms: []
#
# Disease: dizziness        NaN
# Symptoms: []
#
# Disease: loss_of_appetite                    nausea          pain_behind_the_eyes                       back_pain                     muscle_pain    red_spots_over_body                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: loss_of_appetite                    nausea          pain_behind_the_eyes                       back_pain                     muscle_pain    red_spots_over_body                  NaN              NaN              NaN          NaN
#                                  Deng
# Symptoms: []
#
# Disease: loss_of_appetite                    nausea          pain_behind_the_eyes                       back_pain                     muscle_pain    red_spots_over_body                  NaN              NaN              NaN          NaN
#                                  Deng
# Symptoms: []
#
# Disease: loss_of_appetite                    nausea          pain_behind_the_eyes                       back_pain                     muscle_pain    red_spots_over_body                  NaN              NaN              NaN          NaN
#                                  Deng
# Symptoms: []
#
# Disease: loss_of_appetite                    nausea          pain_behind_the_eyes                       back_pain                     muscle_pain    red_spots_over_body                  NaN              NaN              NaN          NaN
#                                  Deng
# Symptoms: []
#
# Disease: skin_rash                    blackheads                      scurring                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN        Na
# Symptoms: []
#
# Disease: skin_rash                     blackheads                      scurring                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN        Na
# Symptoms: []
#
# Disease: skin_rash                       blackheads                      scurring                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN        Na
# Symptoms: []
#
# Disease: skin_rash                     blackheads                      scurring                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN        Na
# Symptoms: []
#
# Disease: skin_rash                        blackheads                      scurring                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN        Na
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease: abdominal_pain              loss_of_appetite              jaundice                    NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease: loss_of_appetite              NaN              NaN          NaN
# Symptoms: []
#
# Disease: Abdominal Aortic Aneurysm                 abdominal_pain             back_pain              fever                       weakness                  shortness_of_breath              abdominal_swelling                  nausea                       NaN                       NaN portray NaN
# Symptoms: []
#
# Disease: fatigue                   fever                     joint_pain                  stiff_neck               swelling_joints               painful_walking                NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN        Na
# Symptoms: []
#
# Disease: dizziness               swelling_joints               painful_walking                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: fever                  loss_appetite            joint_pain                hip_joint_pain               painful_walking                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: soreness               swelling_joints               painful_walking                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: fatigue                swollen_limbs               painful_walking                           NaN                           NaN                NaN                  NaN                  NaN        NaN        NaN        NaN        NaN        NaN        NaN        NaN        Na
# Symptoms: []
#
# Disease: NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: nausea  blurred_and_distorted_vision              excessive_hunger  drying_and_tingling_lips            slurred_speech    irritability  palpitations           NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: nausea  blurred_and_distorted_vision              excessive_hunger  drying_and_tingling_lips            slurred_speech    irritability  palpitations           NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: nausea  blurred_and_distorted_vision              excessive_hunger  drying_and_tingling_lips            slurred_speech    irritability  palpitations           NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: nausea  blurred_and_distorted_vision              excessive_hunger  drying_and_tingling_lips            slurred_speech    irritability  palpitations           NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: nausea  blurred_and_distorted_vision              excessive_hunger  drying_and_tingling_lips            slurred_speech    irritability  palpitations           NaN        NaN        NaN        NaN
# Symptoms: []
#
# Disease: headache                 blurred_vision                    NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: headache                    stiffness  tingling_sensation                   NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: nausea                 vomiting                    NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: numbness_in_limbs          tingling_sensation                  NaN                    NaN                  NaN              NaN              NaN          NaN
# Symptoms: []
#
# Disease: headache                     blurred_vision            irritability              nausea               vomiting           fatigue           fever             chills
# Symptoms: []
#
# Disease: anxiety             insomnia       trembling            NaN          NaN
#                         Hyperthyroidism              fatigue                  mood_swings                weight_loss                  restlessness               sweating                       diarrhoea               fast_heart_rate          excessive_hunger           muscle
# Symptoms: []
#
# Disease: anxiety                NaN         NaN              NaN          NaN
# Symptoms: []
#
# Disease: fever              NaN         NaN              NaN          NaN
# Symptoms: []
#
# Disease: hair_loss            anxiety                   NaN         NaN              NaN          NaN
# Symptoms: []
#
# Disease: increased_appetite           trembling               NaN              NaN          NaN
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease: Dengue             fever                  severe_headache              body_pain          nausea_and_vomiting              skin_rash                             NaN                           NaN               NaN                       NaN                   NaNMalley NaN
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease: Asthma       breathlessness                   coughing                  wheezing                chest_tightness                 shortness_of_breath             sleep_disturbance               NaN                       NaN                   NaN malaria NaN                             NaN
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
#
# Disease:
# Symptoms: []
