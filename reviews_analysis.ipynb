# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-genzeon/AI-ML-Bootcamp-Genzeon-2023/blob/master/reviews_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install cohere altair

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import cohere

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataSet/reviews_data.csv', skiprows=1, names=['reviews'])

# Initialize the Cohere client with your API key
api_key = 'Zohn7P9vs9WgOOP8H6HQIkYesfV5nclp8hsyiTRk'
client = cohere.Client(api_key)

df.head()
# Out:
#                                              reviews
# 0  i updated to the new version on 5/7/19. Now wh...
# 1  Well it does not interface with my fitness dev...
# 2  I am not a fan of this app. The app is not res...
# 3  UPDATE- The app was updated and then it starte...
# 4  App frequently signs me out, will not sync dat...

# %%
# Get text embeddings
def get_embeddings(texts,model='embed-english-v2.0'):
  output = co.embed(
                model=model,
                texts=texts)
  return output.embeddings

# %%
# Embed the dataset
df['reviews_embeds'] = get_embeddings(df['reviews'].tolist())
df.head()
# Out:
#                                              reviews  \
# 0  i updated to the new version on 5/7/19. Now wh...
# 1  Well it does not interface with my fitness dev...
# 2  I am not a fan of this app. The app is not res...
# 3  UPDATE- The app was updated and then it starte...
# 4  App frequently signs me out, will not sync dat...
#
#                                       reviews_embeds
# 0  [2.3066406, 1.296875, 0.057678223, 0.35888672,...
# 1  [-0.65722656, 0.3552246, 0.8701172, 0.16442871...
# 2  [1.2939453, 0.36645508, 0.048553467, 0.7695312...
# 3  [2.3847656, -0.33129883, -0.98583984, 1.433593...
# 4  [1.2646484, 0.18786621, 0.4182129, -0.06378174...
